# %%
import os
import pandas as pd
# Out:
# /Users/nikkosiegfried/opt/anaconda3/lib/python3.9/site-packages/pandas/core/computation/expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.8.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# /Users/nikkosiegfried/opt/anaconda3/lib/python3.9/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.4' currently installed).
#   from pandas.core import (

# %%
df = pd.read_csv('FINAL_DATA/Film_Locations_Geocoded_FINAL.csv')

# %%
def remove_year_and_poster(name):
    words = name.split() 
    return ' '.join(words[:-2])

# %%
title_tconst_dict = {}
for index, row in df.iterrows():
    title = row['Title']
    tconst = row['tconst']
    title_tconst_dict[title] = tconst

# %%
path = 'map/images'
for item in os.listdir(path):
    full_path = os.path.join(path, item)
    title = remove_year_and_poster(item)
    try:
        new = title_tconst_dict[title]
        new_path = os.path.join(path, new)
        os.rename(full_path, new_path)
    except:
        continue

# %%
title_tconst_dict
# Out:
# {'The Californians': 'tt0377043',
#  'Babies': 'tt1020938',
#  'Down Periscope': 'tt0116130',
#  'Shattered': 'tt0102900',
#  'True Believer': 'tt0098524',
#  'The Doctor': 'tt0101746',
#  "Fathers' Day": 'tt0119109',
#  'The Organization': 'tt0067535',
#  'Raising Cain': 'tt0105217',
#  'Just Like Heaven': 'tt0425123',
#  'Confessions of a Burning Man': 'tt0357567',
#  'Beaches': 'tt0094715',
#  'The Laughing Policeman': 'tt0070292',
#  'Psych-Out': 'tt0063469',
#  'Jack': 'tt0116669',
#  'Faces of Death': 'tt0077533',
#  'On the Beach': 'tt0053137',
#  'Fandom': 'tt0417667',
#  'Barbary Coast': 'tt0026097',
#  'Hello Frisco, Hello': 'tt0035982',
#  'The Zodiac': 'tt0371739',
#  'Desperate Measures': 'tt0118966',
#  'Bee Season': 'tt0387059',
#  'House of Sand and Fog': 'tt0315983',
#  'The Nightmare Before Christmas': 'tt0107688',
#  'Nina Takes a Lover': 'tt0110671',
#  'To the Ends of the Earth': 'tt0040887',
#  'Tweek City': 'tt0351885',
#  'American Yearbook': 'tt0386284',
# ...
