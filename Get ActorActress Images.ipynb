# %%
from bing_image_downloader import downloader
import pandas as pd
import os

# %%
df_names = pd.read_csv('FINAL_DATA/Actors_Names_FINAL.csv')

# %%
df_names
# Out:
#         nconst      primaryName birthYear deathYear  \
# 0    nm0000001     Fred Astaire      1899      1987
# 1    nm0000007  Humphrey Bogart      1899      1957
# 2    nm0000008    Marlon Brando      1924      2004
# 3    nm0000012      Bette Davis      1908      1989
# 4    nm0000013        Doris Day      1922      2019
# ..         ...              ...       ...       ...
# 512  nm7851611   Jharrel Jerome      1997        \N
# 513  nm7949518           Jin Ha        \N        \N
# 514  nm8629338     Jimmie Fails      1994        \N
# 515  nm8898449    Penelope Cruz        \N        \N
# 516  nm9771753     Michael Pena        \N        \N
#
#                                      primaryProfession  \
# 0                     Actor,  Miscellaneous,  Producer
# 1                     Actor,  Producer,  Miscellaneous
# 2                            Actor,  Director,  Writer
# 3              Actress,  Make Up Department,  Producer
# 4                   Actress,  Producer,  Miscellaneous
# ...

# %%
for index, row in df_names.iterrows():
    query = f"{row.primaryName} IMDB"
    downloader.download(query, limit=1,  output_dir='map/images', adult_filter_off=True, force_replace=False, timeout=60, verbose=True)
# Out:
# [%] Downloading Images to /Users/nikkosiegfried/Documents/Projects/SF-FILMS-DASHBOARD/map/images/Fred Astaire IMDB
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 1 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://m.media-amazon.com/images/M/MV5BMzMxMjBhMWQtYTM3My00NDdiLTk0N2YtZDg2NjVmZWNmYzY3L2ltYWdlXkEyXkFqcGdeQXVyMjcyMDU4NA@@._V1_FMjpg_UX1000_.jpg
# [%] File Downloaded !
#
#
#
# [%] Done. Downloaded 1 images.
# [%] Downloading Images to /Users/nikkosiegfried/Documents/Projects/SF-FILMS-DASHBOARD/map/images/Humphrey Bogart IMDB
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 1 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://m.media-amazon.com/images/M/MV5BMTIyOTE3MDM5Ml5BMl5BanBnXkFtZTYwMzA2MTM2._V1_UY1200_CR145,0,630,1200_AL_.jpg
# [%] File Downloaded !
#
#
#
# [%] Done. Downloaded 1 images.
# [%] Downloading Images to /Users/nikkosiegfried/Documents/Projects/SF-FILMS-DASHBOARD/map/images/Marlon Brando IMDB
#
#
# [!!]Indexing page: 1
#
# ...

# %%
names_dict = {}
for index, row in df_names.iterrows():
    ncost = row.nconst
    name = row.primaryName
    names_dict[name] = ncost

# %%
directory = 'map/images'

for filename in os.listdir(directory):
    old_file_path = os.path.join(directory, filename)
    if filename[-5:] == ' IMDB':
        if filename[:-5] == 'nan':
            continue
        nconst = names_dict[filename[:-5]]
#     if os.path.isfile(file_path):
        #print(f"File: {file_path}")
        new_file_path = os.path.join(directory, nconst)
        try:
            os.rename(old_file_path, new_file_path)
        except:
            continue

# %%
# Out:
# map/images/nm0593722
# map/images/nm0494432
# map/images/nm0012204
# map/images/nm12089711
# map/images/nm0362766
# map/images/nm4448022
# map/images/nm0001301
# map/images/nm0005476
# map/images/nm0000443
# map/images/nm0000182
# map/images/nm0000404
# map/images/nm0491402
# map/images/nm0588183
# map/images/nm0000724
# map/images/nm0001141
# map/images/nm0000598
# map/images/nm0519225
# map/images/nm0908919
# map/images/nm0765597
# map/images/nm0000688
# map/images/nm12420922
# map/images/nm1065664
# map/images/nm0000245
# map/images/nm0001665
# map/images/nm3010363
# map/images/nm0000028
# map/images/nm0000099
# map/images/nm0000321
# map/images/nm0559144
# map/images/nm1033193
# map/images/nm0515260
# map/images/nm0001627
# map/images/nm1596124
# map/images/nm0766005
# map/images/nm0000775
# map/images/nm3899048
# map/images/nm0000012
# map/images/nm0001718
# map/images/nm0000112
# map/images/nm0000080
# map/images/nm5377144
# map/images/nm1093951
# map/images/nm0000559
# ...
